# %% [markdown]
# <a href="https://colab.research.google.com/github/RuideFu/NPS-Polarization/blob/main/NPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
from astropy.io import fits #import fits io from astropy
import numpy as np #import numpy
import matplotlib.pyplot as plt #import matplotlib

# %% [markdown]
# Import [astropy](https://www.astropy.org/) to do astro related stuff,
# most importantly do fits IO.
# [More on fits](https://en.wikipedia.org/wiki/FITS).
#
# Import [numpy](https://numpy.org/) to make math computation
# and data array manipulation easier.
# Especially astropy heavily utilize numpy as a dependency.
#
# Import [matplotlib](https://matplotlib.org/) to do plotting.
#
# It might be easier to follow in Google Colab to import some libraries later, but it's generally a good practice to import everything at the start of the file.

# %% [markdown]
# # File Parsing

# %%
with fits.open("/content/100703-A.fits") as file:
  file.info() #displays quick info of the file
  data = file['main'].data
# Out:
# Filename: /content/100703-A.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  main          1 PrimaryHDU      60   (740, 757)   float64
#   1  path          1 ImageHDU        61   (740, 757)   float64
#   2  scale         1 ImageHDU        61   (740, 757)   float64
#   3  weight        1 ImageHDU        61   (740, 757)   float64
#   4  correlation    1 ImageHDU        61   (740, 757)   float64
#   5  raw           1 ImageHDU        61   (741, 774)   float64

# %% [markdown]
# This part of the code open, read, and analyze data and metadata from Skynet observation files.
#
# Files should be uploaded to colab with the naming convention of `FILE_ID-CHANNEL`.
#
# To find the readible file path by the python script, simply right click the file then click copy path.

# %% [markdown]
# # Data Processing

# %%
processed_data = np.rot90(data) #simple rotation demo

# %% [markdown]
# Magically process the fits files we get from RC.
# Mainly to get polarization density.
#
# Details TBD.

# %% [markdown]
# # Graph Output

# %%
_, image_array = plt.subplots(1, 2)
image_array[0].imshow(data) #the OG file
image_array[1].imshow(processed_data) #get rotated lol
